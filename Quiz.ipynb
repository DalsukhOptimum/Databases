-- %% [markdown]
-- # [quiz]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [quiz]    Script Date: 09-04-2024 16:41:37 ******/
CREATE DATABASE [quiz]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'quiz', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\quiz.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'quiz_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\quiz_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [quiz] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [quiz].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [quiz] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [quiz] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [quiz] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [quiz] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [quiz] SET ARITHABORT OFF 
GO
ALTER DATABASE [quiz] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [quiz] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [quiz] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [quiz] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [quiz] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [quiz] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [quiz] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [quiz] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [quiz] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [quiz] SET  ENABLE_BROKER 
GO
ALTER DATABASE [quiz] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [quiz] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [quiz] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [quiz] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [quiz] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [quiz] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [quiz] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [quiz] SET RECOVERY FULL 
GO
ALTER DATABASE [quiz] SET  MULTI_USER 
GO
ALTER DATABASE [quiz] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [quiz] SET DB_CHAINING OFF 
GO
ALTER DATABASE [quiz] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [quiz] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [quiz] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [quiz] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'quiz', N'ON'
GO
ALTER DATABASE [quiz] SET QUERY_STORE = ON
GO
ALTER DATABASE [quiz] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[compony]

-- %%
USE [quiz]
GO

-- %%
/****** Object:  Table [dbo].[compony]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[compony](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Question] [varchar](500) NULL,
	[Answer] [varchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[education]

-- %%
/****** Object:  Table [dbo].[education]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[education](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Question] [varchar](500) NULL,
	[Answer] [varchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MaxScore]

-- %%
/****** Object:  Table [dbo].[MaxScore]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MaxScore](
	[Id] [int] NOT NULL,
	[Score] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[QuizName]

-- %%
/****** Object:  Table [dbo].[QuizName]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[QuizName](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[QuizName] [varchar](80) NULL,
	[CreatedTime] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[compony]

-- %%
SET IDENTITY_INSERT [dbo].[compony] ON 
INSERT [dbo].[compony] ([Id], [Question], [Answer]) VALUES (1, N'name of compony', N'optimum')
INSERT [dbo].[compony] ([Id], [Question], [Answer]) VALUES (2, N'location', N'ahmedabad')
SET IDENTITY_INSERT [dbo].[compony] OFF
GO

-- %% [markdown]
-- # [dbo].[education]

-- %%
SET IDENTITY_INSERT [dbo].[education] ON 
INSERT [dbo].[education] ([Id], [Question], [Answer]) VALUES (1, N'console.log() syntax of', N'javascript')
INSERT [dbo].[education] ([Id], [Question], [Answer]) VALUES (2, N'console.writeline() syntax of', N'c sharp')
INSERT [dbo].[education] ([Id], [Question], [Answer]) VALUES (3, N'cout<<"" synatx of', N'c++')
SET IDENTITY_INSERT [dbo].[education] OFF
GO

-- %% [markdown]
-- # [dbo].[MaxScore]

-- %%
INSERT [dbo].[MaxScore] ([Id], [Score]) VALUES (1, 3)
GO

-- %% [markdown]
-- # [dbo].[QuizName]

-- %%
SET IDENTITY_INSERT [dbo].[QuizName] ON 
INSERT [dbo].[QuizName] ([Id], [QuizName], [CreatedTime]) VALUES (1026, N'compony', CAST(N'2024-02-29T10:59:36.153' AS DateTime))
INSERT [dbo].[QuizName] ([Id], [QuizName], [CreatedTime]) VALUES (1027, N'education', CAST(N'2024-02-29T13:21:22.670' AS DateTime))
SET IDENTITY_INSERT [dbo].[QuizName] OFF
GO

-- %% [markdown]
-- # [dbo].[CustomerRegister]

-- %%
/****** Object:  StoredProcedure [dbo].[CustomerRegister]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[CustomerRegister]
@Name varchar(200),
@phone bigint,
@Email varchar(30),
@Adress varchar(500),
@CreatedTime datetime,
@UpdatedTime datetime,
@OperationType varchar(200),
@Exist bigint
as
begin try
 if(@OperationType = 'CustomerRegister')
 begin
 insert into Customer values(@Name,@phone,@Email,@Adress,GETDATE(),null,1);
 end;

 if(@OperationType = 'CustomerExist')
 begin
 select @Exist = COUNT(*) from Customer where Name = @Name ;
 end 

 end try 
 begin catch
 PRINT ERROR_MESSAGE()
 END catch
GO

-- %% [markdown]
-- # [dbo].[InsertQuestion]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertQuestion]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[InsertQuestion] 
@Question varchar(MAX),
@Answer varchar(MAX),
@QuizName varchar(100)
as 
begin try
declare @query nvarchar(MAX);
set @query = 'insert into ' +@QuizName+ '(Question,Answer) values(''' +@Question+ ''','  +'''' + @Answer+ ''''+ ')';

exec sp_executesql @query ;
end try
begin catch
print ERROR_MESSAGE();
END CATCH ;
GO

-- %% [markdown]
-- # [dbo].[InsertQuizName]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertQuizName]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[InsertQuizName]
@QuizName varchar(100)
as
begin try
insert into QuizName(QuizName,CreatedTime) values(@QuizName,GETDATE());
end try
begin catch
print ERROR_MESSAGE();
END CATCH ;
GO

-- %% [markdown]
-- # [dbo].[ShowAllQuiz]

-- %%
/****** Object:  StoredProcedure [dbo].[ShowAllQuiz]    Script Date: 09-04-2024 16:41:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[ShowAllQuiz]
@QuizName varchar(100),
@OperationType varchar(80),
@UserScore int,
@MaxScore int out
as
begin try
if(@OperationType = 'SeeQuizNames')
begin
select * from QuizName ;
end

if(@OperationType = 'SeeQuestions')
begin
declare @Query NVARCHAR(MAX);
set @Query  = 'select * from '+ @QuizName ;
EXEC sp_executesql @Query;
end;

if(@OperationType = 'SeeMaxScore')
begin
select @MaxScore = Score from MaxScore ;
end;

if(@OperationType = 'updateScore')
begin
update MaxScore set Score = @UserScore where Id = 1 ;
end;

end try 
begin catch
print ERROR_MESSAGE();
END CATCH ;	
GO

-- %% [markdown]
-- # [quiz]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [quiz] SET  READ_WRITE 
GO
