-- %% [markdown]
-- # [EventModule]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EventModule]    Script Date: 09-04-2024 16:38:52 ******/
CREATE DATABASE [EventModule]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EventModule', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EventModule.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EventModule_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\EventModule_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [EventModule] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EventModule].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EventModule] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EventModule] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EventModule] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EventModule] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EventModule] SET ARITHABORT OFF 
GO
ALTER DATABASE [EventModule] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [EventModule] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EventModule] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EventModule] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EventModule] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EventModule] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EventModule] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EventModule] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EventModule] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EventModule] SET  ENABLE_BROKER 
GO
ALTER DATABASE [EventModule] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EventModule] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EventModule] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EventModule] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EventModule] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EventModule] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EventModule] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EventModule] SET RECOVERY FULL 
GO
ALTER DATABASE [EventModule] SET  MULTI_USER 
GO
ALTER DATABASE [EventModule] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EventModule] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EventModule] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EventModule] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EventModule] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EventModule] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'EventModule', N'ON'
GO
ALTER DATABASE [EventModule] SET QUERY_STORE = ON
GO
ALTER DATABASE [EventModule] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ActivityTbl]

-- %%
USE [EventModule]
GO

-- %%
/****** Object:  Table [dbo].[ActivityTbl]    Script Date: 09-04-2024 16:38:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ActivityTbl](
	[ActivityId] [bigint] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Description] [varchar](max) NOT NULL,
	[Price] [bigint] NULL,
	[EventId] [bigint] NOT NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ActivityId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AdminTbl]

-- %%
/****** Object:  Table [dbo].[AdminTbl]    Script Date: 09-04-2024 16:38:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AdminTbl](
	[AdminTblId] [bigint] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Email] [varchar](320) NOT NULL,
	[Password] [varchar](100) NOT NULL,
	[Mobile] [varchar](10) NOT NULL,
	[Address] [varchar](100) NOT NULL,
	[UpdatedTime] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[AdminTblId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EventTbl]

-- %%
/****** Object:  Table [dbo].[EventTbl]    Script Date: 09-04-2024 16:38:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EventTbl](
	[EventId] [bigint] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[StartDate] [datetime] NOT NULL,
	[EndDate] [datetime] NOT NULL,
	[Description] [varchar](max) NOT NULL,
	[Image] [varchar](max) NOT NULL,
	[IsActive] [bigint] NOT NULL,
	[IsPublish] [bigint] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[EventId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserLoginTbl]

-- %%
/****** Object:  Table [dbo].[UserLoginTbl]    Script Date: 09-04-2024 16:38:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserLoginTbl](
	[UserLoginTblId] [bigint] IDENTITY(1,1) NOT NULL,
	[Email] [varchar](320) NOT NULL,
	[Password] [varchar](100) NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[ISActive] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UserLoginTblId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserTbl]

-- %%
/****** Object:  Table [dbo].[UserTbl]    Script Date: 09-04-2024 16:38:52 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserTbl](
	[UserTblId] [bigint] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Email] [varchar](320) NOT NULL,
	[Mobile] [varchar](10) NOT NULL,
	[Address] [varchar](200) NOT NULL,
	[CreatedTime] [datetime] NOT NULL,
	[Password] [varchar](100) NOT NULL,
	[UpdatedTime] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[UserTblId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ActivityTbl]

-- %%
SET IDENTITY_INSERT [dbo].[ActivityTbl] ON 
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (2, N'rangoli', N'drawing rangoli', NULL, 3, CAST(N'2024-04-16T13:44:00.000' AS DateTime), CAST(N'2024-04-25T13:45:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (3, N'jujjjj', N'jjjjjjjjjjjjjjjjj', NULL, 3, CAST(N'2024-04-23T14:57:00.000' AS DateTime), CAST(N'2024-04-25T14:57:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (4, N'rakhdi', N'this is festival of brother and sister ', NULL, 10, CAST(N'2024-04-07T14:59:00.000' AS DateTime), CAST(N'2024-04-08T14:59:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (5, N'Rangoli', N'Rangoli is an art form that originates from the Indian subcontinent, in which patterns are created o', NULL, 11, CAST(N'2024-04-09T12:06:00.000' AS DateTime), CAST(N'2024-04-10T11:06:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (6, N'Color Competition', N'this is a game in which we will play with the colors ', NULL, 11, CAST(N'2024-04-10T11:07:00.000' AS DateTime), CAST(N'2024-04-11T11:07:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (7, N'demo game', N'this is demo purpose activity', 500, 5, CAST(N'2024-04-08T11:11:00.000' AS DateTime), CAST(N'2024-04-10T11:11:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (8, N'ddsd', N'dsdsdd', 455, 12, CAST(N'2024-04-22T12:16:00.000' AS DateTime), CAST(N'2024-04-23T12:16:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (10, N'mghmbnmbnh', N'gghj,kjhk,k', 500, 15, CAST(N'2024-04-09T14:39:00.000' AS DateTime), CAST(N'2024-04-10T14:39:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (11, N'ugyuyu', N'yuiyuiyui', 500, 4, CAST(N'2024-04-15T15:56:00.000' AS DateTime), CAST(N'2024-04-18T15:56:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (12, N'cvxcvxcvxc', N'vfsdgdffgfg', 200, 7, CAST(N'2024-04-23T16:16:00.000' AS DateTime), CAST(N'2024-04-25T16:16:00.000' AS DateTime))
INSERT [dbo].[ActivityTbl] ([ActivityId], [Name], [Description], [Price], [EventId], [StartDate], [EndDate]) VALUES (13, N'iiuu', N'iiiiujhgythgh', NULL, 8, CAST(N'2024-04-24T16:33:00.000' AS DateTime), CAST(N'2024-04-26T16:33:00.000' AS DateTime))
SET IDENTITY_INSERT [dbo].[ActivityTbl] OFF
GO

-- %% [markdown]
-- # [dbo].[AdminTbl]

-- %%
SET IDENTITY_INSERT [dbo].[AdminTbl] ON 
INSERT [dbo].[AdminTbl] ([AdminTblId], [Name], [Email], [Password], [Mobile], [Address], [UpdatedTime]) VALUES (1, N'Dalsukh', N'naneradalsukh@gmail.com', N'Dal@2002', N'7573942052', N'Dwarka', NULL)
SET IDENTITY_INSERT [dbo].[AdminTbl] OFF
GO

-- %% [markdown]
-- # [dbo].[EventTbl]

-- %%
SET IDENTITY_INSERT [dbo].[EventTbl] ON 
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (3, N'janmastami', CAST(N'2024-04-04T11:27:00.000' AS DateTime), CAST(N'2024-04-18T11:27:00.000' AS DateTime), N'festival of shree krishna', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Imagesok.png', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (4, N'dhuleti', CAST(N'2024-04-29T11:32:00.000' AS DateTime), CAST(N'2024-04-30T11:33:00.000' AS DateTime), N'festival of color', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Imagesok.png', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (5, N'demo', CAST(N'2024-04-16T11:34:00.000' AS DateTime), CAST(N'2024-04-18T11:34:00.000' AS DateTime), N'sdasdsdaujyu', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Imagesok.png', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (7, N'ddddd', CAST(N'2024-04-06T11:56:00.000' AS DateTime), CAST(N'2024-04-07T11:56:00.000' AS DateTime), N'ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd dddddddddddddddddd', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\11-56-43.png', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (8, N'sunday', CAST(N'2024-04-08T14:53:00.000' AS DateTime), CAST(N'2024-04-17T14:53:00.000' AS DateTime), N'23333333 f', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\14-54-34.png', 1, 0)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (9, N'ssss', CAST(N'2024-04-22T15:11:00.000' AS DateTime), CAST(N'2024-04-24T15:11:00.000' AS DateTime), N'dhkdf', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\15-11-52.png', 1, 0)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (10, N'rakshabandhan', CAST(N'2024-04-07T14:57:00.000' AS DateTime), CAST(N'2024-04-08T14:57:00.000' AS DateTime), N'efffffffffffffff        vf       vvvvvvvvvvvvv vvvvvv vv', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\14-58-33.png', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (11, N'Holi', CAST(N'2024-04-09T11:05:00.000' AS DateTime), CAST(N'2024-04-11T11:05:00.000' AS DateTime), N'Holi is a Hindu festival that takes place every spring. It''s all about new beginnings — Holi welcomes the spring season and celebrates the end of winter. The Holi festival always falls on Purnima, or the day of the full moon.', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\11-06-00.png', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (12, N'try', CAST(N'2024-04-22T12:16:00.000' AS DateTime), CAST(N'2024-04-24T12:16:00.000' AS DateTime), N'try this', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\12-16-19.png', 1, 0)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (14, N'asdsdasd', CAST(N'2024-04-01T14:31:00.000' AS DateTime), CAST(N'2024-04-10T14:31:00.000' AS DateTime), N'sdsdfsdfsd', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\14-31-30.svg', 1, 0)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (15, N'svg try', CAST(N'2024-04-21T14:37:00.000' AS DateTime), CAST(N'2024-04-25T14:37:00.000' AS DateTime), N'jsdasgdjvzdjdf zdf', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\14-38-20.svg', 1, 1)
INSERT [dbo].[EventTbl] ([EventId], [Name], [StartDate], [EndDate], [Description], [Image], [IsActive], [IsPublish]) VALUES (16, N'dsdfdfd', CAST(N'2024-04-29T15:56:00.000' AS DateTime), CAST(N'2024-04-30T15:56:00.000' AS DateTime), N'dfdfdfff', N'C:\Users\dalsu\OneDrive\Desktop\Intern\EventModule\EventModule\Images\15-56-44.jpg', 1, 0)
SET IDENTITY_INSERT [dbo].[EventTbl] OFF
GO

-- %% [markdown]
-- # [dbo].[UserTbl]

-- %%
SET IDENTITY_INSERT [dbo].[UserTbl] ON 
INSERT [dbo].[UserTbl] ([UserTblId], [Name], [Email], [Mobile], [Address], [CreatedTime], [Password], [UpdatedTime]) VALUES (7, N'Nanera Dalsukh', N'naneradalsukh@gmail.com', N'7573942025', N'Dwarka', CAST(N'2024-04-03T15:58:27.607' AS DateTime), N'Dal@2002', NULL)
INSERT [dbo].[UserTbl] ([UserTblId], [Name], [Email], [Mobile], [Address], [CreatedTime], [Password], [UpdatedTime]) VALUES (8, N'virat kohli', N'virat@gmail.com', N'7573942025', N'jamnagar', CAST(N'2024-04-03T16:01:47.510' AS DateTime), N'Vir@2002', NULL)
INSERT [dbo].[UserTbl] ([UserTblId], [Name], [Email], [Mobile], [Address], [CreatedTime], [Password], [UpdatedTime]) VALUES (9, N'Robert', N'robert@gmail.com', N'4566544565', N'Jamnagar', CAST(N'2024-04-04T17:07:39.900' AS DateTime), N'dfgfgfg', NULL)
SET IDENTITY_INSERT [dbo].[UserTbl] OFF
GO

-- %% [markdown]
-- # [UQ__AdminTbl__A9D105343322D447]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__AdminTbl__A9D105343322D447]    Script Date: 09-04-2024 16:38:53 ******/
ALTER TABLE [dbo].[AdminTbl] ADD UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__EventTbl__737584F638D433B0]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__EventTbl__737584F638D433B0]    Script Date: 09-04-2024 16:38:53 ******/
ALTER TABLE [dbo].[EventTbl] ADD UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__UserLogi__A9D10534AD5EA8DE]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__UserLogi__A9D10534AD5EA8DE]    Script Date: 09-04-2024 16:38:53 ******/
ALTER TABLE [dbo].[UserLoginTbl] ADD UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__UserTbl__A9D10534B907F20D]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__UserTbl__A9D10534B907F20D]    Script Date: 09-04-2024 16:38:53 ******/
ALTER TABLE [dbo].[UserTbl] ADD UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__ActivityT__Event__4E88ABD4]

-- %%
ALTER TABLE [dbo].[ActivityTbl]  WITH CHECK ADD FOREIGN KEY([EventId])
REFERENCES [dbo].[EventTbl] ([EventId])
GO

-- %% [markdown]
-- # [dbo].[Add_Activity_SP]

-- %%
/****** Object:  StoredProcedure [dbo].[Add_Activity_SP]    Script Date: 09-04-2024 16:38:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[Add_Activity_SP] --'uno','playing uno',1,'2024-04-03 15:58:27.607','2024-04-04 15:58:27.607'
@Name varchar(100),
@Description  varchar(100),
@EventId bigint,
@StartDate datetime,
@EndDate datetime

as 
begin
declare @Id bigint ;

select @Id = ActivityId from ActivityTbl where Name = @Name AND EventId = @EventId ;

if @Id IS NOT NULL
begin
select 'Already Exists Activity' as ResponseMessage, 0 as ID 
return
end

insert into ActivityTbl values(@Name,@Description,null,@EventId,@StartDate,@EndDate);
select 'Addedd successfully' as ResponseMessage, 1 as ID 
end 

GO

-- %% [markdown]
-- # [dbo].[Add_Event_SP]

-- %%
/****** Object:  StoredProcedure [dbo].[Add_Event_SP]    Script Date: 09-04-2024 16:38:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[Add_Event_SP]
@Name varchar(100),
@Description varchar(MAX),
@StartDate datetime,
@Enddate datetime,
@Image varchar(MAX)

as
begin



declare @Id bigint ;
select @Id	= EventId from EventTbl where Name = @Name ;

if @Id IS NOT NULL
begin
select 'Already Exist' as ResponseMessage, 0 as ID
return
end 

insert into EventTbl values(@Name,@StartDate,@Enddate,@Description,@Image,1,0);
select 'Addedd successfully' as ResponseMessage, 1 as ID 
end 





GO

-- %% [markdown]
-- # [dbo].[LoginSP]

-- %%
/****** Object:  StoredProcedure [dbo].[LoginSP]    Script Date: 09-04-2024 16:38:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc  [dbo].[LoginSP] 
@Email varchar(320),
@Password varchar(100),
@Flag varchar(100)
as
begin 

if @Flag IS null
begin
select 'Please Provide flag' as ResponseMessage, 0 as ID 
return 
end 

declare  @Id bigint ; 

if @Flag = 'UserLogin'
begin
select @Id = UserTBLId from UserTbl where Email = @Email AND Password = @Password ;  

if @Id is null
begin
select 'provided credetails is wrong' as ResponseMessage , 0 as ID 
return
end
select 'Login successfully' as ResponseMessage, 1 as ID
end

if @Flag = 'AdminLogin'
begin
select @Id = AdminTblId from AdminTbl where Email = @Email AND Password = @Password ;  
if @Id is null
begin
select 'provided credetails is wrong' as ResponseMessage , 0 as ID 
return
end
select 'Login successfully' as ResponseMessage, 1 as ID
end

end 

GO

-- %% [markdown]
-- # [dbo].[Publish_AddPrice_SP]

-- %%
/****** Object:  StoredProcedure [dbo].[Publish_AddPrice_SP]    Script Date: 09-04-2024 16:38:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[Publish_AddPrice_SP]
@Price bigint,
@ActivityId bigint,
@EventId bigint,
@Flag varchar(100)
as
begin

if @Flag = 'Publish'
begin

declare @count bigint ;
select @count = COUNT(ActivityId) from ActivityTbl where EventId = @EventId ;

if @count = 0
begin 
select 'You can not publish this becuase you have to first add atleast one activity' as ResponseMessage, 0 as ID
return 
end

update EventTbl set IsPublish =1 where EventId = @EventId ;
select 'Publish successfully' as ResponseMessage, 1 as ID
end 

if @Flag = 'AddPrice'
begin
update ActivityTbl set Price = @Price where ActivityId = @ActivityId ;
select 'Updated Successfully' as ResponseMessage, 1 as ID 
end

end 
GO

-- %% [markdown]
-- # [dbo].[RegisterUser_SP]

-- %%
/****** Object:  StoredProcedure [dbo].[RegisterUser_SP]    Script Date: 09-04-2024 16:38:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc  [dbo].[RegisterUser_SP]  --'Dalsukh','naneradalsukh@gmail.com','4566544568','Dwarka','Dal@2002'
@Name varchar(100),
@Email varchar(320),
@Mobile varchar(10),
@Address varchar(100),
@Password varchar(100)
as
begin 
declare @Id bigint ;
select @Id = UserTblId from UserTbl where Email = @Email ;

if @Id IS NOT NULL
begin 
select 'User are already Registered' as Resultmessage, 0 as ID
return
end 

insert into UserTbl values(@Name,@Email,@Mobile,@Address,GETDATE(),@Password,null) ;
select 'Register Successfully' as Resultmessage,1 as ID;
select * from UserTbl where Email = @Email ;
end

select * from UserTbl;
GO

-- %% [markdown]
-- # [dbo].[Showing_Event_Activity_SP]

-- %%
/****** Object:  StoredProcedure [dbo].[Showing_Event_Activity_SP]    Script Date: 09-04-2024 16:38:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[Showing_Event_Activity_SP] --1,'ActibityShow'
@EventId bigint,
@Flag varchar(1000)

as 
begin 

declare @count bigint ;

if @Flag IS NULL
begin
select 'please provide valid flag' as ResponseMessage, 0 as ID 
return
end

if @Flag = 'AdminEvents'
begin
select @count = COUNT(EventId) from EventTbl where IsPublish = 0 ;
if @count = 0
begin
select 'Do not have any Event To publish' as ResponseMessage, 0 as ID
return 
end

select 'Fetched Successfully' as ResponseMessage, 1 as ID 
select * from EventTbl where IsPublish = 0; 
end

if @Flag = 'EmployeeEvent'

begin
select @count = COUNT(EventId) from EventTbl where IsPublish = 1 ;
if @count = 0
begin
select 'DO not have any scheduled by Admin' as ResponseMessage, 0 as ID
return 
end

select 'Fetched Successfully' as ResponseMessage, 1 as ID 
select * from EventTbl  where IsPublish = 1 ;
end

if @Flag = 'ActibityShow'
begin


select @count = COUNT(ActivityId) from ActivityTbl where EventId = @EventId ;
if @count = 0
begin
select 'Do not have any activity yet' as ResponseMessage, 0 as ID
return 
end

select 'Fetched Successfully' as ResponseMessage, 1 as ID 
select * from ActivityTbl where EventId = @EventId ;
end 

end 




GO

-- %% [markdown]
-- # [EventModule]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [EventModule] SET  READ_WRITE 
GO
